# %%
import ultralytics
print("YOLO instalado! Versão:", ultralytics.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\gusta\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO instalado! Versão: 8.4.53

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pWy03tnBFMmsGbwSkYrH")
project = rf.workspace("www-oedzr").project("sickle-pd9yp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to sickle-1 in yolov8:: 100%|██████████| 696/696 [00:00<00:00, 1730.98it/s]

# %%
import os
for raiz, pastas, arquivos in os.walk(dataset.location):
    nivel = raiz.replace(dataset.location, '').count(os.sep)
    print('  ' * nivel + os.path.basename(raiz) + '/')
    for f in arquivos[:2]:
        print('  ' * (nivel+1) + f)
# Out:
# sickle-1/
#   data.yaml
#   README.dataset.txt
#   train/
#     images/
#       -1-_jpg.rf.2ac61610adc81e5c1ad7b345602c26c8.jpg
#       -1-_jpg.rf.67129d93bc125502c697fe9332c42eda.jpg
#     labels/
#       -1-_jpg.rf.2ac61610adc81e5c1ad7b345602c26c8.txt
#       -1-_jpg.rf.67129d93bc125502c697fe9332c42eda.txt
